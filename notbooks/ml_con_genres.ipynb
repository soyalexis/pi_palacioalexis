# %%
import pandas as pd


archivo_csv1 = 'gamescompleto.csv'
archivo_csv2 = 'itemscompleto.csv'
archivo_csv3 = 'df_reviews_completo3sin23.csv'

dfgames = pd.read_csv(archivo_csv1)
dfitems = pd.read_csv(archivo_csv2)
dfreviews = pd.read_csv(archivo_csv3)

# %%
dfgames.head()
# Out:
#              publisher                                             genres  \
# 0            Kotoshiro  ['Action', 'Casual', 'Indie', 'Simulation', 'S...
# 1     Making Fun, Inc.       ['Free to Play', 'Indie', 'RPG', 'Strategy']
# 2         Poolians.com  ['Casual', 'Free to Play', 'Indie', 'Simulatio...
# 3                 彼岸领域                  ['Action', 'Adventure', 'Casual']
# 4  Trickjump Games Ltd              ['Action', 'Adventure', 'Simulation']
#
#                  item_name                    title  \
# 0      Lost Summoner Kitty      Lost Summoner Kitty
# 1                Ironbound                Ironbound
# 2  Real Pool 3D - Poolians  Real Pool 3D - Poolians
# 3                  弹炸人2222                  弹炸人2222
# 4    Battle Royale Trainer    Battle Royale Trainer
#
#                                                  url release_date  \
# 0  http://store.steampowered.com/app/761140/Lost_...   2018-01-04
# 1  http://store.steampowered.com/app/643980/Ironb...   2018-01-04
# 2  http://store.steampowered.com/app/670290/Real_...   2017-07-24
# 3     http://store.steampowered.com/app/767400/2222/   2017-12-07
# 4  http://store.steampowered.com/app/772540/Battl...   2018-01-04
#
#                                                 tags  \
# 0  ['Strategy', 'Action', 'Indie', 'Casual', 'Sim...
# 1  ['Free to Play', 'Strategy', 'Indie', 'RPG', '...
# 2  ['Free to Play', 'Simulation', 'Sports', 'Casu...
# 3                  ['Action', 'Adventure', 'Casual']
# 4  ['Action', 'Adventure', 'Simulation', 'FPS', '...
#
#                                          reviews_url  \
# 0  http://steamcommunity.com/app/761140/reviews/?...
# 1  http://steamcommunity.com/app/643980/reviews/?...
# 2  http://steamcommunity.com/app/670290/reviews/?...
# 3  http://steamcommunity.com/app/767400/reviews/?...
# 4  http://steamcommunity.com/app/772540/reviews/?...
#
#                                                specs         price  \
# 0                                  ['Single-player']          4.99
# 1  ['Single-player', 'Multi-player', 'Online Mult...  Free To Play
# 2  ['Single-player', 'Multi-player', 'Online Mult...  Free to Play
# 3                                  ['Single-player']          0.99
# 4            ['Single-player', 'Steam Achievements']          3.99
#
#    early_access   item_id            developer
# 0         False  761140.0            Kotoshiro
# 1         False  643980.0     Secret Level SRL
# 2         False  670290.0         Poolians.com
# 3         False  767400.0                 彼岸领域
# 4         False  772540.0  Trickjump Games Ltd

# %%
dfgames2 = dfgames[['item_id','item_name','genres']]

# %%
dfgames2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28852 entries, 0 to 28851
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   item_id    28851 non-null  float64
#  1   item_name  28851 non-null  object
#  2   genres     28852 non-null  object
# dtypes: float64(1), object(2)
# memory usage: 676.3+ KB

# %%
dfgames2.dropna(inplace=True)
# Out:
# <ipython-input-191-aead95715930>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfgames2.dropna(inplace=True)

# %%
dfgames2.isnull().sum()
# Out:
# item_id      0
# item_name    0
# genres       0
# dtype: int64

# %%
num_filas_dupli = dfgames2.duplicated().sum()
print(f"Número de filas duplicadas: {num_filas_dupli}")
# Out:
# Número de filas duplicadas: 1

# %%
dfgames2.drop_duplicates(subset=['item_name', 'item_id'], keep='first', inplace=True)
# borramos duplicados solo si la fila completa esta duplicada
# Out:
# <ipython-input-194-c9ee4cf51a91>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfgames2.drop_duplicates(subset=['item_name', 'item_id'], keep='first', inplace=True)

# %%
dfgames2['item_id'] = pd.to_numeric(dfgames2['item_id'], errors='coerce').fillna(0).astype(int)
# convertimos la columna en formato int
# Out:
# <ipython-input-195-a0f0ae521338>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfgames2['item_id'] = pd.to_numeric(dfgames2['item_id'], errors='coerce').fillna(0).astype(int)

# %%
dfgames2.info()
#verificamos que no hay nulos y los formatos
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28849 entries, 0 to 28851
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   item_id    28849 non-null  int64
#  1   item_name  28849 non-null  object
#  2   genres     28849 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 901.5+ KB

# %%
dfreviews.head()
# Out:
#              user_id                                           user_url funny  \
# 0  76561197970982479  http://steamcommunity.com/profiles/76561197970...   NaN
# 1            js41637               http://steamcommunity.com/id/js41637   NaN
# 2          evcentric             http://steamcommunity.com/id/evcentric   NaN
# 3              doctr                 http://steamcommunity.com/id/doctr   NaN
# 4          maplemage             http://steamcommunity.com/id/maplemage   NaN
#
#    Fecha_posteo last_edited  item_id  \
# 0        2011.0         NaN     1250
# 1        2011.0         NaN    22200
# 2        2011.0         NaN    43110
# 3        2014.0         NaN   251610
# 4        2013.0         NaN   227300
#
#                                            helpful  recommend  \
# 0                                   No ratings yet       True
# 1                                   No ratings yet       True
# 2                                   No ratings yet       True
# 3  15 of 20 people (75%) found this review helpful       True
# 4     0 of 1 people (0%) found this review helpful       True
#
#    sentiment_analysis
# 0                   2
# 1                   2
# 2                   1
# 3                   2
# 4                   1

# %%
dfreviews2=dfreviews[['user_id','item_id','recommend','sentiment_analysis']]

# %%
dfreviews2.head()
# Out:
#              user_id  item_id  recommend  sentiment_analysis
# 0  76561197970982479     1250       True                   2
# 1            js41637    22200       True                   2
# 2          evcentric    43110       True                   1
# 3              doctr   251610       True                   2
# 4          maplemage   227300       True                   1

# %%
merged_df = pd.merge(dfgames2, dfreviews2, on='item_id', how='inner')

# %%
merged_df
# Out:
#        item_id                       item_name                         genres  \
# 0       282010            Carmageddon Max Pack  ['Action', 'Indie', 'Racing']
# 1           70                       Half-Life                     ['Action']
# 2           70                       Half-Life                     ['Action']
# 3           70                       Half-Life                     ['Action']
# 4           70                       Half-Life                     ['Action']
# ...        ...                             ...                            ...
# 50422       80  Counter-Strike: Condition Zero                     ['Action']
# 50423       80  Counter-Strike: Condition Zero                     ['Action']
# 50424       80  Counter-Strike: Condition Zero                     ['Action']
# 50425       80  Counter-Strike: Condition Zero                     ['Action']
# 50426       80  Counter-Strike: Condition Zero                     ['Action']
#
#                   user_id  recommend  sentiment_analysis
# 0       76561198076055973       True                   1
# 1      AppoGetsSuperAdmin       True                   1
# 2       76561198051084367       True                   0
# 3              DropBear99       True                   0
# 4            hecaton_john       True                   2
# ...                   ...        ...                 ...
# 50422                 NaN      False                   1
# 50423                 NaN       True                   2
# 50424                 NaN       True                   2
# 50425                 NaN       True                   1
# 50426                 NaN       True                   0
#
# [50427 rows x 6 columns]

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50427 entries, 0 to 50426
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   item_id             50427 non-null  int64
#  1   item_name           50427 non-null  object
#  2   genres              50427 non-null  object
#  3   user_id             21955 non-null  object
#  4   recommend           50427 non-null  bool
#  5   sentiment_analysis  50427 non-null  int64
# dtypes: bool(1), int64(2), object(3)
# memory usage: 2.4+ MB

# %%
# Elimina las filas con valores nulos solo en la columna 'user_id'
merged_df = merged_df.dropna(subset=['user_id'])

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21955 entries, 0 to 50419
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   item_id             21955 non-null  int64
#  1   item_name           21955 non-null  object
#  2   genres              21955 non-null  object
#  3   user_id             21955 non-null  object
#  4   recommend           21955 non-null  bool
#  5   sentiment_analysis  21955 non-null  int64
# dtypes: bool(1), int64(2), object(3)
# memory usage: 1.0+ MB

# %%
df_reducido = merged_df.sample(frac=0.5, random_state=1)

# %%
df_reducido.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10978 entries, 14002 to 47240
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   item_id             10978 non-null  int64
#  1   item_name           10978 non-null  object
#  2   genres              10978 non-null  object
#  3   user_id             10978 non-null  object
#  4   recommend           10978 non-null  bool
#  5   sentiment_analysis  10978 non-null  int64
# dtypes: bool(1), int64(2), object(3)
# memory usage: 525.3+ KB

# %%
df_reducido['recommend'] = df_reducido['recommend'].astype(int)

# %%
#df_reducido['genres'] = df_reducido['genres'].str.replace(r"[\[\]']", '', regex=True)

# %%
df_reducido
# Out:
#        item_id                    item_name  \
# 14002   268750                     Magicite
# 18208   310950             Street Fighter V
# 38616   219640   Chivalry: Medieval Warfare
# 44743    34900  Bad Rats: the Rats' Revenge
# 10045   202170                Sleeping Dogs
# ...        ...                          ...
# 35531   104900               ORION: Prelude
# 46470      440              Team Fortress 2
# 31125   232790                   Broken Age
# 38429     4920          Natural Selection 2
# 47240      440              Team Fortress 2
#
#                                         genres            user_id  recommend  \
# 14002  ['Action', 'Adventure', 'Indie', 'RPG']  76561198047354266          1
# 18208                               ['Action']  76561198051433352          0
# 38616                      ['Action', 'Indie']     PrimeDarkEther          1
# 44743                                ['Indie']      TonytheTurkey          1
# 10045                  ['Action', 'Adventure']  samsamandhecancan          1
# ...                                        ...                ...        ...
# 35531  ['Action', 'Adventure', 'Indie', 'RPG']         Rotomaniac          1
# 46470               ['Action', 'Free to Play']  76561198004624665          1
# 31125         ['Adventure', 'Casual', 'Indie']    hitlersokiguess          1
# 38429          ['Action', 'Indie', 'Strategy']         RebelKirby          1
# 47240               ['Action', 'Free to Play']  76561198229845636          1
#
#        sentiment_analysis
# 14002                   2
# 18208                   1
# 38616                   0
# 44743                   2
# 10045                   2
# ...                   ...
# 35531                   0
# 46470                   2
# 31125                   1
# 38429                   0
# 47240                   1
#
# [10978 rows x 6 columns]

# %%
import ast

# Convierte la columna 'genres' de cadenas a listas
df_reducido['genres'] = df_reducido['genres'].apply(ast.literal_eval)

# %%
# Aplicar One-Hot Encoding a la columna 'genres'
genres_encoded = pd.get_dummies(df_reducido['genres'].apply(pd.Series).stack()).sum(level=0)

# Concatenar los datos codificados con el DataFrame original
df_encoded = pd.concat([df_reducido, genres_encoded], axis=1)
# Out:
# <ipython-input-211-204408927686>:2: FutureWarning: Using the level keyword in DataFrame and Series aggregations is deprecated and will be removed in a future version. Use groupby instead. df.sum(level=1) should use df.groupby(level=1).sum().
#   genres_encoded = pd.get_dummies(df_reducido['genres'].apply(pd.Series).stack()).sum(level=0)

# %%
df_encoded.head(3)
# Out:
#        item_id                   item_name                           genres  \
# 14002   268750                    Magicite  [Action, Adventure, Indie, RPG]
# 18208   310950            Street Fighter V                         [Action]
# 38616   219640  Chivalry: Medieval Warfare                  [Action, Indie]
#
#                  user_id  recommend  sentiment_analysis  Action  Adventure  \
# 14002  76561198047354266          1                   2       1          1
# 18208  76561198051433352          0                   1       1          0
# 38616     PrimeDarkEther          1                   0       1          0
#
#        Animation &amp; Modeling  Audio Production  ...  Massively Multiplayer  \
# 14002                         0                 0  ...                      0
# 18208                         0                 0  ...                      0
# 38616                         0                 0  ...                      0
#
#        RPG  Racing  Simulation  Software Training  Sports  Strategy  \
# 14002    1       0           0                  0       0         0
# 18208    0       0           0                  0       0         0
# 38616    0       0           0                  0       0         0
#
#        Utilities  Video Production  Web Publishing
# 14002          0                 0               0
# 18208          0                 0               0
# 38616          0                 0               0
#
# [3 rows x 26 columns]

# %%
columnas_a_borrar = ['item_id', 'item_name', 'genres', 'user_id']
numeric_df = df_encoded.drop(columnas_a_borrar, axis=1)

# %%
numeric_df
# Out:
#        recommend  sentiment_analysis  Action  Adventure  \
# 14002          1                   2       1          1
# 18208          0                   1       1          0
# 38616          1                   0       1          0
# 44743          1                   2       0          0
# 10045          1                   2       1          1
# ...          ...                 ...     ...        ...
# 35531          1                   0       1          1
# 46470          1                   2       1          0
# 31125          1                   1       0          1
# 38429          1                   0       1          0
# 47240          1                   1       1          0
#
#        Animation &amp; Modeling  Audio Production  Casual  \
# 14002                         0                 0       0
# 18208                         0                 0       0
# 38616                         0                 0       0
# 44743                         0                 0       0
# 10045                         0                 0       0
# ...                         ...               ...     ...
# 35531                         0                 0       0
# 46470                         0                 0       0
# 31125                         0                 0       1
# 38429                         0                 0       0
# 47240                         0                 0       0
#
#        Design &amp; Illustration  Early Access  Education  ...  \
# 14002                          0             0          0  ...
# 18208                          0             0          0  ...
# 38616                          0             0          0  ...
# 44743                          0             0          0  ...
# 10045                          0             0          0  ...
# ...                          ...           ...        ...  ...
# 35531                          0             0          0  ...
# 46470                          0             0          0  ...
# 31125                          0             0          0  ...
# 38429                          0             0          0  ...
# 47240                          0             0          0  ...
#
#        Massively Multiplayer  RPG  Racing  Simulation  Software Training  \
# 14002                      0    1       0           0                  0
# 18208                      0    0       0           0                  0
# 38616                      0    0       0           0                  0
# 44743                      0    0       0           0                  0
# 10045                      0    0       0           0                  0
# ...                      ...  ...     ...         ...                ...
# 35531                      0    1       0           0                  0
# 46470                      0    0       0           0                  0
# 31125                      0    0       0           0                  0
# 38429                      0    0       0           0                  0
# 47240                      0    0       0           0                  0
#
#        Sports  Strategy  Utilities  Video Production  Web Publishing
# 14002       0         0          0                 0               0
# 18208       0         0          0                 0               0
# 38616       0         0          0                 0               0
# 44743       0         0          0                 0               0
# 10045       0         0          0                 0               0
# ...       ...       ...        ...               ...             ...
# 35531       0         0          0                 0               0
# 46470       0         0          0                 0               0
# 31125       0         0          0                 0               0
# 38429       0         1          0                 0               0
# 47240       0         0          0                 0               0
#
# [10978 rows x 22 columns]

# %%
df_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10978 entries, 14002 to 47240
# Data columns (total 26 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   item_id                    10978 non-null  int64
#  1   item_name                  10978 non-null  object
#  2   genres                     10978 non-null  object
#  3   user_id                    10978 non-null  object
#  4   recommend                  10978 non-null  int64
#  5   sentiment_analysis         10978 non-null  int64
#  6   Action                     10978 non-null  uint8
#  7   Adventure                  10978 non-null  uint8
#  8   Animation &amp; Modeling   10978 non-null  uint8
#  9   Audio Production           10978 non-null  uint8
#  10  Casual                     10978 non-null  uint8
#  11  Design &amp; Illustration  10978 non-null  uint8
#  12  Early Access               10978 non-null  uint8
#  13  Education                  10978 non-null  uint8
#  14  Free to Play               10978 non-null  uint8
#  15  Indie                      10978 non-null  uint8
#  16  Massively Multiplayer      10978 non-null  uint8
#  17  RPG                        10978 non-null  uint8
#  18  Racing                     10978 non-null  uint8
#  19  Simulation                 10978 non-null  uint8
#  20  Software Training          10978 non-null  uint8
#  21  Sports                     10978 non-null  uint8
#  22  Strategy                   10978 non-null  uint8
#  23  Utilities                  10978 non-null  uint8
#  24  Video Production           10978 non-null  uint8
#  25  Web Publishing             10978 non-null  uint8
# dtypes: int64(3), object(3), uint8(20)
# memory usage: 1.0+ MB

# %%
from sklearn.metrics.pairwise import cosine_similarity
# Calcular la similitud del coseno entre usuarios
user_similarity = cosine_similarity(numeric_df)

# Crear un DataFrame con la matriz de similitud
user_similarity_df = pd.DataFrame(user_similarity, index=df_reducido['user_id'], columns=df_reducido['user_id'])

print(user_similarity_df)
# Out:
# user_id            76561198047354266  76561198051433352  PrimeDarkEther  \
# user_id
# 76561198047354266           1.000000           0.707107        0.577350
# 76561198051433352           0.707107           1.000000        0.408248
# PrimeDarkEther              0.577350           0.408248        1.000000
# TonytheTurkey               0.816497           0.577350        0.471405
# samsamandhecancan           0.881917           0.801784        0.436436
# ...                              ...                ...             ...
# Rotomaniac                  0.745356           0.316228        0.774597
# 76561198004624665           0.755929           0.801784        0.436436
# hitlersokiguess             0.745356           0.316228        0.516398
# RebelKirby                  0.500000           0.353553        0.866025
# 76561198229845636           0.666667           0.707107        0.577350
#
# user_id            TonytheTurkey  samsamandhecancan  epicbudgie  optamusjebus  \
# user_id
# 76561198047354266       0.816497           0.881917    0.666667      0.384900
# 76561198051433352       0.577350           0.801784    0.471405      0.408248
# PrimeDarkEther          0.471405           0.436436    0.577350      0.666667
# TonytheTurkey           1.000000           0.771517    0.544331      0.235702
# samsamandhecancan       0.771517           1.000000    0.629941      0.436436
# ...                          ...                ...         ...           ...
# Rotomaniac              0.365148           0.507093    0.596285      0.516398
# 76561198004624665       0.771517           0.857143    0.503953      0.654654
# hitlersokiguess         0.730297           0.676123    0.596285      0.258199
# RebelKirby              0.408248           0.377964    0.666667      0.577350
# 76561198229845636       0.612372           0.755929    0.500000      0.866025
#
# user_id            76561198082387555   benoz11  76561198192373206  ...  \
# user_id                                                            ...
# 76561198047354266           0.816497  0.881917           0.816497  ...
# 76561198051433352           0.866025  0.801784           0.577350  ...
# PrimeDarkEther              0.471405  0.654654           0.235702  ...
# TonytheTurkey               0.833333  0.925820           0.833333  ...
# samsamandhecancan           0.925820  0.857143           0.771517  ...
# ...                              ...       ...                ...  ...
# Rotomaniac                  0.365148  0.507093           0.365148  ...
# 76561198004624665           0.925820  0.857143           0.771517  ...
# hitlersokiguess             0.547723  0.676123           0.547723  ...
# RebelKirby                  0.408248  0.566947           0.204124  ...
# 76561198229845636           0.816497  0.755929           0.612372  ...
#
# user_id            76561198086872866  Gaarashuffles  madcow2234  thefailwhale  \
# user_id
# 76561198047354266           0.666667       0.881917    0.384900      0.755929
# 76561198051433352           0.707107       0.801784    0.408248      0.801784
# PrimeDarkEther              0.577350       0.436436    0.666667      0.436436
# TonytheTurkey               0.612372       0.771517    0.235702      0.771517
# samsamandhecancan           0.755929       1.000000    0.436436      0.857143
# ...                              ...            ...         ...           ...
# Rotomaniac                  0.447214       0.507093    0.516398      0.338062
# 76561198004624665           0.944911       0.857143    0.654654      1.000000
# hitlersokiguess             0.447214       0.676123    0.258199      0.507093
# RebelKirby                  0.500000       0.377964    0.577350      0.377964
# 76561198229845636           1.000000       0.755929    0.866025      0.944911
#
# user_id            76561198084265658  Rotomaniac  76561198004624665  \
# user_id
# 76561198047354266           0.666667    0.745356           0.755929
# 76561198051433352           0.707107    0.316228           0.801784
# PrimeDarkEther              0.577350    0.774597           0.436436
# TonytheTurkey               0.612372    0.365148           0.771517
# samsamandhecancan           0.755929    0.507093           0.857143
# ...                              ...         ...                ...
# Rotomaniac                  0.447214    1.000000           0.338062
# 76561198004624665           0.944911    0.338062           1.000000
# hitlersokiguess             0.447214    0.600000           0.507093
# RebelKirby                  0.500000    0.670820           0.377964
# 76561198229845636           1.000000    0.447214           0.944911
#
# user_id            hitlersokiguess  RebelKirby  76561198229845636
# user_id
# 76561198047354266         0.745356    0.500000           0.666667
# 76561198051433352         0.316228    0.353553           0.707107
# PrimeDarkEther            0.516398    0.866025           0.577350
# TonytheTurkey             0.730297    0.408248           0.612372
# samsamandhecancan         0.676123    0.377964           0.755929
# ...                            ...         ...                ...
# Rotomaniac                0.600000    0.670820           0.447214
# 76561198004624665         0.507093    0.377964           0.944911
# hitlersokiguess           1.000000    0.447214           0.447214
# RebelKirby                0.447214    1.000000           0.500000
# 76561198229845636         0.447214    0.500000           1.000000
#
# [10978 rows x 10978 columns]

# %%
user_similarity_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10978 entries, 76561198047354266 to 76561198229845636
# Columns: 10978 entries, 76561198047354266 to 76561198229845636
# dtypes: float64(10978)
# memory usage: 919.8+ MB

# %%
user_similarity_df.head()
# Out:
# user_id            76561198047354266  76561198051433352  PrimeDarkEther  \
# user_id
# 76561198047354266           1.000000           0.707107        0.577350
# 76561198051433352           0.707107           1.000000        0.408248
# PrimeDarkEther              0.577350           0.408248        1.000000
# TonytheTurkey               0.816497           0.577350        0.471405
# samsamandhecancan           0.881917           0.801784        0.436436
#
# user_id            TonytheTurkey  samsamandhecancan  epicbudgie  optamusjebus  \
# user_id
# 76561198047354266       0.816497           0.881917    0.666667      0.384900
# 76561198051433352       0.577350           0.801784    0.471405      0.408248
# PrimeDarkEther          0.471405           0.436436    0.577350      0.666667
# TonytheTurkey           1.000000           0.771517    0.544331      0.235702
# samsamandhecancan       0.771517           1.000000    0.629941      0.436436
#
# user_id            76561198082387555   benoz11  76561198192373206  ...  \
# user_id                                                            ...
# 76561198047354266           0.816497  0.881917           0.816497  ...
# 76561198051433352           0.866025  0.801784           0.577350  ...
# PrimeDarkEther              0.471405  0.654654           0.235702  ...
# TonytheTurkey               0.833333  0.925820           0.833333  ...
# samsamandhecancan           0.925820  0.857143           0.771517  ...
#
# user_id            76561198086872866  Gaarashuffles  madcow2234  thefailwhale  \
# user_id
# 76561198047354266           0.666667       0.881917    0.384900      0.755929
# 76561198051433352           0.707107       0.801784    0.408248      0.801784
# PrimeDarkEther              0.577350       0.436436    0.666667      0.436436
# TonytheTurkey               0.612372       0.771517    0.235702      0.771517
# samsamandhecancan           0.755929       1.000000    0.436436      0.857143
#
# user_id            76561198084265658  Rotomaniac  76561198004624665  \
# user_id
# 76561198047354266           0.666667    0.745356           0.755929
# 76561198051433352           0.707107    0.316228           0.801784
# PrimeDarkEther              0.577350    0.774597           0.436436
# TonytheTurkey               0.612372    0.365148           0.771517
# samsamandhecancan           0.755929    0.507093           0.857143
#
# user_id            hitlersokiguess  RebelKirby  76561198229845636
# user_id
# 76561198047354266         0.745356    0.500000           0.666667
# 76561198051433352         0.316228    0.353553           0.707107
# PrimeDarkEther            0.516398    0.866025           0.577350
# TonytheTurkey             0.730297    0.408248           0.612372
# samsamandhecancan         0.676123    0.377964           0.755929
#
# [5 rows x 10978 columns]

# %%
def recomendacion_usuario(user_id):
    # Verifica si el usuario está en el DataFrame de similitud
    if user_id not in user_similarity_df.index:
        return "Usuario no encontrado"

    # Obtiene la fila de similitud del usuario
    user_similarity = user_similarity_df.loc[user_id]

    # Ordena los usuarios por similitud en orden descendente
    similar_users = user_similarity.sort_values(ascending=False)[1:]  # Excluye al propio usuario

    # Filtra los juegos jugados por usuarios similares
    user_data = df_reducido[df_reducido['user_id'] == user_id]
    games_played = user_data['item_name'].unique()

    # Genera una lista de juegos recomendados
    recommendations = []
    for similar_user_id, similarity_score in similar_users.items():
        similar_user_data = df_reducido[df_reducido['user_id'] == similar_user_id]
        for game in similar_user_data['item_name']:
            if game not in games_played:
                recommendations.append(game)
            if len(recommendations) >= 5:  # Devuelve 5 recomendaciones, puedes ajustar este número
                break

    return recommendations[:5]  # Devuelve las primeras 5 recomendaciones

# %%
recomendacion_usuario('samsamandhecancan')
# Out:
# ['Batman: Arkham Asylum Game of the Year Edition',
#  'Grand Theft Auto V',
#  'Just Cause 2: Multiplayer Mod',
#  'Call of Duty®: Black Ops III',
#  'Grand Theft Auto V']
